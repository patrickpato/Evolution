# %%
import numpy as np 
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
from scipy.stats import boxcox 
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder, LabelEncoder
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report, f1_score, accuracy_score
from scipy.linalg import pinv2, inv
import time
import numpy as np
import multiprocessing as mp
import pickle
from tqdm.notebook import tqdm
import warnings
warnings.filterwarnings("ignore")

# %%
def load_data(path):
    return pd.read_csv(path)
win10_df = load_data("../input/intrusion-detection-data/windows10_dataset.csv")

# %%
features = win10_df.drop(columns=['ts', 'type'], axis=1)
numeric_features = features.select_dtypes(exclude=['object'])
numeric_features.head(2)
# Out:
#    Processor_DPC_Rate  Process_Pool_Paged Bytes  Process_Working_Set_ Private  \
# 0                   4                  15446344                    1185267712
# 1                   9                  15448880                    1188397056
#
#    Process_Working_Set_Peak  Process_Page_File Bytes  \
# 0                5639348224               2536640512
# 1                5639348224               2535768064
#
#    Process_Virtual_Bytes Peak  Process_Page_File Bytes Peak  \
# 0             112000000000000                    9375539200
# 1             112000000000000                    9379713024
#
#    Process_Private_Bytes  Process_Elapsed_Time  Process_Virtual_Bytes  \
# 0             2536640512                     0        112000000000000
# 1             2535768064                     0        112000000000000
#
#    Process_Creating Process ID  Process_Pool Nonpaged Bytes  \
# 0                            0                      2447032
# 1                            0                      2451920
#
#    Process_Working Set  Process_ID Process  Process_Thread Count  \
# 0           1319534592                   0                   789
# 1           1322864640                   0                   787
#
#    Process_Priority Base  Process_Handle Count  \
# 0                      0                 29996
# 1                      0                 29992
#
#    Network_I(Intel R _82574L_GNC)TCP_APS  \
# 0                                      0
# 1                                      0
#
#    Network_I(Intel R _82574L_GNC) Packets Received Unknown  \
# 0                                                  0
# 1                                                  0
#
#    Network_I(Intel R _82574L_GNC) Packets Outbound Errors  \
# 0                                                  0
# 1                                                  0
#
#    Network_I(Intel R _82574L_GNC) Packets Received Discarded  \
# 0                                                  0
# 1                                                  0
#
#    Network_I(Intel R _82574L_GNC) Packets Outbound Discarded  \
# 0                                                  0
# 1                                                  0
#
#    Network_I(Intel R _82574L_GNC) Output Queue Length  \
# 0                                                  0
# 1                                                  0
#
#    Network_I(Intel R _82574L_GNC) Current Bandwidth  \
# 0                                        1000000000
# 1                                        1000000000
#
#    Network_I(Intel R _82574L_GNC) TCP Active RSC Connections  \
# 0                                                  0
# 1                                                  0
#
#    Network_I(Intel R _82574L_GNC) Offloaded Connections  \
# 0                                                  0
# 1                                                  0
#
#    Network_I(Intel R _82574L_GNC) Packets Received Errors  \
# 0                                                  0
# 1                                                  0
#
#    Memory Pool Paged Bytes  Memory Free & Zero Page List Bytes  \
# 0                284635136                             4018176
# 1                284782592                             7233536
#
#    Memory Cache Bytes Peak  Memory System Code Resident Bytes  \
# 0                815652864                            1466368
# 1                815652864                            1466368
#
#    Memory Available Bytes  Memory Commit Limit  Memory Available KBytes  \
# 0               261980160           6444666880                   255840
# 1               261197824           6444666880                   255076
#
#    Memory Cache Bytes  Memory Pool Nonpaged Bytes  \
# 0            18944000                    89763840
# 1            16445440                    89747456
#
#    Memory System Cache Resident Bytes  \
# 0                                   0
# 1                                   0
#
#    Memory Long-Term Average Standby Cache Lifetime (s)  \
# 0                                                 48
# 1                                                 48
#
#    Memory Standby Cache Reserve Bytes  Memory System Code Total Bytes  \
# 0                             5668864                         3825664
# 1                             2158592                         3825664
#
#    Memory Standby Cache Core Bytes  Memory System Driver Resident Bytes  \
# 0                        157052928                              2957312
# 1                        157036544                              2985984
#
#    Memory Standby Cache Normal Priority Bytes  Memory Pool Paged Allocs  \
# 0                                    95240192                    164783
# 1                                    94769152                    164891
#
#    Memory Pool Nonpaged Allocs  Memory pct_ Committed Bytes In Use  \
# 0                       122023                           53.693804
# 1                       122068                           53.687639
#
#    Memory Free System Page Table Entries  Memory Available MBytes  \
# 0                               12229087                      249
# 1                               12229106                      249
#
#    Memory Modified Page List Bytes  Memory Committed Bytes  \
# 0                           962560              3460386816
# 1                          1376256              3459989504
#
#    Memory System Driver Total Bytes  Memory Pool Paged Resident Bytes  \
# 0                          17117184                          83619840
# 1                          17158144                          83984384
#
#    LogicalDisk(_Total) pct_ Free Space  \
# 0                            82.156219
# 1                            82.156219
#
#    LogicalDisk(_Total) Current Disk Queue Length  \
# 0                                              0
# 1                                              0
#
#    LogicalDisk(_Total) Free Megabytes  label
# 0                              167984      0
# 1                              167984      0

# %%
#scaling the data
def min_max_scaler(df):
    min_max_scaler_df = df.copy()
    for col in df.columns:
        min_max_scaler_df[col] = (df[col]-df[col].min())/(df[col].max()-df[col].min())
    return min_max_scaler_df
min_max_df = min_max_scaler(numeric_features)
min_max_df.head(2)
# Out:
#    Processor_DPC_Rate  Process_Pool_Paged Bytes  Process_Working_Set_ Private  \
# 0            0.020513                  0.254279                      0.347702
# 1            0.046154                  0.254362                      0.348839
#
#    Process_Working_Set_Peak  Process_Page_File Bytes  \
# 0                  0.509926                 0.274078
# 1                  0.509926                 0.273947
#
#    Process_Virtual_Bytes Peak  Process_Page_File Bytes Peak  \
# 0                    0.125998                      0.676939
# 1                    0.125998                      0.677290
#
#    Process_Private_Bytes  Process_Elapsed_Time  Process_Virtual_Bytes  \
# 0               0.274078                   NaN               0.125998
# 1               0.273947                   NaN               0.125998
#
#    Process_Creating Process ID  Process_Pool Nonpaged Bytes  \
# 0                          NaN                     0.016574
# 1                          NaN                     0.016630
#
#    Process_Working Set  Process_ID Process  Process_Thread Count  \
# 0             0.142423                 NaN               0.05419
# 1             0.143232                 NaN               0.05293
#
#    Process_Priority Base  Process_Handle Count  \
# 0                    NaN              0.227913
# 1                    NaN              0.227830
#
#    Network_I(Intel R _82574L_GNC)TCP_APS  \
# 0                                    0.0
# 1                                    0.0
#
#    Network_I(Intel R _82574L_GNC) Packets Received Unknown  \
# 0                                                NaN
# 1                                                NaN
#
#    Network_I(Intel R _82574L_GNC) Packets Outbound Errors  \
# 0                                                NaN
# 1                                                NaN
#
#    Network_I(Intel R _82574L_GNC) Packets Received Discarded  \
# 0                                                NaN
# 1                                                NaN
#
#    Network_I(Intel R _82574L_GNC) Packets Outbound Discarded  \
# 0                                                NaN
# 1                                                NaN
#
#    Network_I(Intel R _82574L_GNC) Output Queue Length  \
# 0                                                NaN
# 1                                                NaN
#
#    Network_I(Intel R _82574L_GNC) Current Bandwidth  \
# 0                                               1.0
# 1                                               1.0
#
#    Network_I(Intel R _82574L_GNC) TCP Active RSC Connections  \
# 0                                                0.0
# 1                                                0.0
#
#    Network_I(Intel R _82574L_GNC) Offloaded Connections  \
# 0                                                NaN
# 1                                                NaN
#
#    Network_I(Intel R _82574L_GNC) Packets Received Errors  \
# 0                                                NaN
# 1                                                NaN
#
#    Memory Pool Paged Bytes  Memory Free & Zero Page List Bytes  \
# 0                 0.474041                            0.001572
# 1                 0.474401                            0.002831
#
#    Memory Cache Bytes Peak  Memory System Code Resident Bytes  \
# 0                      1.0                           0.409611
# 1                      1.0                           0.409611
#
#    Memory Available Bytes  Memory Commit Limit  Memory Available KBytes  \
# 0                0.089327             0.309638                 0.089327
# 1                0.089055             0.309638                 0.089055
#
#    Memory Cache Bytes  Memory Pool Nonpaged Bytes  \
# 0            0.023806                    0.335761
# 1            0.020587                    0.335599
#
#    Memory System Cache Resident Bytes  \
# 0                                 0.0
# 1                                 0.0
#
#    Memory Long-Term Average Standby Cache Lifetime (s)  \
# 0                                           0.003126
# 1                                           0.003126
#
#    Memory Standby Cache Reserve Bytes  Memory System Code Total Bytes  \
# 0                            0.005038                        0.865616
# 1                            0.001918                        0.865616
#
#    Memory Standby Cache Core Bytes  Memory System Driver Resident Bytes  \
# 0                         0.607586                         1.680291e-07
# 1                         0.607523                         1.696582e-07
#
#    Memory Standby Cache Normal Priority Bytes  Memory Pool Paged Allocs  \
# 0                                    0.069145                  0.258663
# 1                                    0.068803                  0.258832
#
#    Memory Pool Nonpaged Allocs  Memory pct_ Committed Bytes In Use  \
# 0                     0.438832                            0.386306
# 1                     0.438994                            0.386221
#
#    Memory Free System Page Table Entries  Memory Available MBytes  \
# 0                               0.000017                 0.089318
# 1                               0.000017                 0.089318
#
#    Memory Modified Page List Bytes  Memory Committed Bytes  \
# 0                         0.001114                0.191387
# 1                         0.001592                0.191353
#
#    Memory System Driver Total Bytes  Memory Pool Paged Resident Bytes  \
# 0                          0.040099                          0.180379
# 1                          0.042339                          0.181282
#
#    LogicalDisk(_Total) pct_ Free Space  \
# 0                             0.125954
# 1                             0.125954
#
#    LogicalDisk(_Total) Current Disk Queue Length  \
# 0                                            0.0
# 1                                            0.0
#
#    LogicalDisk(_Total) Free Megabytes  label
# 0                            0.121252    0.0
# 1                            0.121252    0.0

# %%
numeric_features['target'] = win10_df['type'].values

# %%
le = LabelEncoder()
numeric_features['target'] = le.fit_transform(numeric_features['target'])

# %%
X = numeric_features.drop(columns = ['target'], axis=1)
y = numeric_features[['target']]
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3, random_state=42)
X_train, X_test = np.array(X_train), np.array(X_test)
y_train, y_test = np.array(y_train), np.array(y_test)

# %%
class ExtremeLearningMachine():
    def __init__(self, hidden_units, activation_function,  x, y, C, elm_type, one_hot=True, random_type=None):
        self.hidden_units = hidden_units
        self.activation_function = activation_function
        self.random_type = random_type
        self.x = x
        self.y = y
        self.C = C
        self.class_num = np.unique(self.y).shape[0]     
        self.beta = np.zeros((self.hidden_units, self.class_num))   
        self.elm_type = elm_type
        self.one_hot = one_hot

        # if classification problem and one_hot == True
        if elm_type == 'clf' and self.one_hot:
            self.one_hot_label = np.zeros((self.y.shape[0], self.class_num))
            for i in range(self.y.shape[0]):
                self.one_hot_label[i, int(self.y[i])] = 1

        # Randomly generate the weight matrix and bias vector from input to hidden layer
        # 'uniform': uniform distribution
        # 'normal': normal distribution
        if self.random_type == 'uniform':
            self.W = np.random.uniform(low=0, high=1, size=(self.hidden_units, self.x.shape[1]))
            self.b = np.random.uniform(low=0, high=1, size=(self.hidden_units, 1))
        if self.random_type == 'normal':
            self.W = np.random.normal(loc=0, scale=0.5, size=(self.hidden_units, self.x.shape[1]))
            self.b = np.random.normal(loc=0, scale=0.5, size=(self.hidden_units, 1))
        if self.random_type == "ES":
            self.W = jittered_weights
            self.b = np.random.uniform(low=0, high=1, size=(self.hidden_units, 1))

    # compute the output of hidden layer according to different activation function
    def __input2hidden(self, x):
        self.temH = np.dot(self.W, x.T) + self.b

        if self.activation_function == 'sigmoid':
            self.H = 1/(1 + np.exp(- self.temH))

        if self.activation_function == 'relu':
            self.H = self.temH * (self.temH > 0)

        if self.activation_function == 'sin':
            self.H = np.sin(self.temH)

        if self.activation_function == 'tanh':
            self.H = (np.exp(self.temH) - np.exp(-self.temH))/(np.exp(self.temH) + np.exp(-self.temH))

        if self.activation_function == 'leaky_relu':
            self.H = np.maximum(0, self.temH) + 0.1 * np.minimum(0, self.temH)

        return self.H

    # compute the output
    def __hidden2output(self, H):
        self.output = np.dot(H.T, self.beta)
        return self.output

    def fit(self, algorithm):
        self.time1 = time.clock()   # compute running time
        self.H = self.__input2hidden(self.x)
        if self.elm_type == 'clf':
            if self.one_hot:
                self.y_temp = self.one_hot_label
            else:
                self.y_temp = self.y
        if self.elm_type == 'reg':
            self.y_temp = self.y
        # no regularization
        if algorithm == 'no_re':
            self.beta = np.dot(pinv2(self.H.T), self.y_temp)
        # faster algorithm 1
        if algorithm == 'solution1':
            self.tmp1 = inv(np.eye(self.H.shape[0])/self.C + np.dot(self.H, self.H.T))
            self.tmp2 = np.dot(self.tmp1, self.H)
            self.beta = np.dot(self.tmp2, self.y_temp)
        # faster algorithm 2
        if algorithm == 'solution2':
            self.tmp1 = inv(np.eye(self.H.shape[0])/self.C + np.dot(self.H, self.H.T))
            self.tmp2 = np.dot(self.H.T, self.tmp1)
            self.beta = np.dot(self.tmp2.T, self.y_temp)
        self.time2 = time.clock()

        # compute the results
        self.result = self.__hidden2output(self.H)
        # If the problem if classification problem, the output is softmax
        if self.elm_type == 'clf':
            self.result = np.exp(self.result)/np.sum(np.exp(self.result), axis=1).reshape(-1, 1)

        # Evaluate training results
        # If problem is classification, compute the accuracy
        # If problem is regression, compute the RMSE
        if self.elm_type == 'clf':
            self.y_ = np.where(self.result == np.max(self.result, axis=1).reshape(-1, 1))[1]
            self.correct = 0
            for i in range(self.y.shape[0]):
                if self.y_[i] == self.y[i]:
                    self.correct += 1
            self.train_score = self.correct/self.y.shape[0]
        if self.elm_type == 'reg':
            self.train_score = np.sqrt(np.sum((self.result - self.y) * (self.result - self.y))/self.y.shape[0])
        train_time = str(self.time2 - self.time1)
        return self.beta, self.train_score, train_time
    def predict(self, x):
        self.H = self.__input2hidden(x)
        self.y_ = self.__hidden2output(self.H)
        if self.elm_type == 'clf':
            self.y_ = np.where(self.y_ == np.max(self.y_, axis=1).reshape(-1, 1))[1]

        return self.y_

    def score(self, x, y):
        self.prediction = self.predict(x)
        if self.elm_type == 'clf':
            self.correct = 0
            for i in range(y.shape[0]):
                if self.prediction[i] == y[i]:
                    self.correct += 1
            self.test_score = self.correct/y.shape[0]
        if self.elm_type == 'reg':
            self.test_score = np.sqrt(np.sum((self.result - self.y) * (self.result - self.y))/self.y.shape[0])

        return self.test_score
    def get_weights(self):
        return self.W

# %%
#Testing ELM model
sample_elm = ExtremeLearningMachine(hidden_units=32, activation_function="relu", random_type="normal", 
                                   x = X_train, y=y_train, C=0.1, elm_type = "clf")
_, _, _ = sample_elm.fit("solution2")
sample_weights = sample_elm.get_weights()
sample_weights
# Out:
# array([[-0.25557831, -0.34791748,  0.34584772, ..., -0.05333463,
#         -0.52969007,  0.33963127],
#        [-0.10500117,  0.16747768, -0.33247503, ..., -0.1002816 ,
#          0.59640882,  0.19816131],
#        [-0.65266304, -0.12165668,  0.30549448, ...,  0.42496643,
#          0.54009733,  0.00969804],
#        ...,
#        [-0.16308679,  0.41847881, -0.035182  , ...,  0.10812587,
#          0.2918096 , -0.6381724 ],
#        [-0.2851999 , -0.44791599,  0.13678561, ...,  0.06541673,
#          1.05839233,  0.27544302],
#        [ 0.51417463,  0.41937208,  0.10099896, ...,  0.6830846 ,
#          0.5739126 ,  0.80405349]])

# %%
#checking model accuracy
test_predictions = sample_elm.predict(X_test) 
print(accuracy_score(test_predictions, y_test))
# Out:
# 0.905123691281386

# %%
def fitness_func(sample_weights, y_train):
    model = ExtremeLearningMachine(hidden_units=32, activation_function="relu", random_type="ES", 
                                  x=X_train, y=y_train, C = 0.1, elm_type="clf")
    _, _, _ = model.fit("solution1")
    train_predictions = model.predict(X_train)
    fit_score = f1_score(train_predictions, y_train, average="weighted")
    return fit_score

# %%
#testing fitness score function
jittered_weights = sample_weights + .0001
trial_score = fitness_func(jittered_weights, y_train)
trial_score
# Out:
# 0.9234155793996197

# %%
#A quick function that jitters the primary parameters to diffrent state
def jitter(mother_params, state_dict):
    params_try = mother_params + SIGMA*state_dict # we will intiialize SIGMA later
    return params_try

# %%
def calculate_population_fitness(pop, mother_vector, y_train):
    fitness = np.zeros(pop.shape[0])
    for i, params in enumerate(pop):
        p_try = jitter(mother_vector, params)
        fitness[i] = fitness_func(p_try, y_train)
    return fitness

# %%
def test(mother_parameters, y_test):
    model = ExtremeLearningMachine(hidden_units=32, activation_function='relu', random_type="ES", x=X_train, y=y_train, C=0.1, elm_type="clf") 
    _, _, _ = model.fit("solution1")
    predictions = model.predict(X_test)
    return accuracy_score(predictions, y_test)

# %%
SIGMA = 0.0001
LR = 0.001
POPULATION_SIZE=32
ITERATIONS = 500

# %%
num_params = sample_weights.shape[1]
num_params
# Out:
# 56

# %%
np.random.seed(2022)
for iteration in tqdm(range(10)): 
    pop = np.random.randn(POPULATION_SIZE, num_params)
    fitness = calculate_population_fitness(pop, sample_weights, y_train)
    # normalize the fitness
    normalized_fitness = (fitness - np.mean(fitness)) / np.std(fitness)
    # update mother vector with the fitness values
    mother_vector = sample_weights + (LR / (POPULATION_SIZE * SIGMA)) * np.matmul(pop.T, normalized_fitness)
    if iteration % 1 == 0:
        reward = fitness_func(mother_vector, y_train)
        acc = test(mother_vector, y_test)
        print(f"Iteration: {iteration}, Reward:{reward}, Accuracy: {acc * 100}")
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Iteration: 0, Reward:0.9234155793996197, Accuracy: 90.52163439266191
# Iteration: 1, Reward:0.9234689570231914, Accuracy: 90.53089965718522
# Iteration: 2, Reward:0.9234925317294692, Accuracy: 90.50310386361531
# Iteration: 3, Reward:0.9233960778595948, Accuracy: 90.50310386361531
# Iteration: 4, Reward:0.9234925317294692, Accuracy: 90.5123691281386
# Iteration: 5, Reward:0.9234925317294692, Accuracy: 90.5123691281386
# Iteration: 6, Reward:0.9235341138801013, Accuracy: 90.5123691281386
# Iteration: 7, Reward:0.9234925317294692, Accuracy: 90.50310386361531
# Iteration: 8, Reward:0.9235680997880004, Accuracy: 90.5123691281386
# Iteration: 9, Reward:0.9234824764077538, Accuracy: 90.5123691281386
